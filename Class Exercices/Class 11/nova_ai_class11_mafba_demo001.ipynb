# %% [markdown]
# # 🔍 Exploring Agentic Frameworks - Basic Agent (Python)
#
# ## 📋 Learning Objectives
#
# This notebook explores the fundamental concepts of the Microsoft Agent Framework through a basic agent implementation. You'll learn core agentic patterns and understand how intelligent agents work under the hood.
#
# **What You'll Discover:**
# - 🏗️ **Agent Architecture**: Understanding the basic structure of AI agents
# - 🛠️ **Tool Integration**: How agents use external functions to extend capabilities
# - 💬 **Conversation Flow**: Managing multi-turn conversations and context
# - 🔧 **Configuration Patterns**: Best practices for agent setup and management
#
# ## 🎯 Key Concepts Covered
#
# ### Agentic Framework Principles
# - **Autonomy**: How agents make independent decisions
# - **Reactivity**: Responding to environmental changes and user inputs
# - **Proactivity**: Taking initiative based on goals and context
# - **Social Ability**: Interacting through natural language
#
# ### Technical Components
# - **ChatAgent**: Core agent orchestration and conversation management
# - **Tool Functions**: Extending agent capabilities with custom functions
# - **OpenAI Integration**: Leveraging language models through standardized APIs
# - **Environment Management**: Secure configuration and credential handling
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework --pre
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# AZUREOAI_KEY=your_azure_openai_key
# AZUREOAI_ENDPOINT=https://models.inference.ai.azure.com
# AZUREOAI_MODEL_ID=gpt-4o
# ```
#
# ## 🔧 Technical Stack
#
# **Core Technologies:**
# - Microsoft Agent Framework (Python)
# - Azure OpenAI API integration
# - OpenAI-compatible client patterns
# - Environment-based configuration
#
# **Agent Capabilities:**
# - Natural language understanding and generation
# - Function calling and tool usage
# - Context-aware responses
# - Extensible architecture
#
# ## 📚 Framework Comparison
#
# This example demonstrates the Microsoft Agent Framework approach compared to other agentic frameworks:
#
# | Feature | Microsoft Agent Framework | Other Frameworks |
# |---------|-------------------------|------------------|
# | **Integration** | Native Microsoft ecosystem | Varied compatibility |
# | **Simplicity** | Clean, intuitive API | Often complex setup |
# | **Extensibility** | Easy tool integration | Framework-dependent |
# | **Enterprise Ready** | Built for production | Varies by framework |
#
# ## 🚀 Getting Started
#
# Follow the cells below to build your first basic agent and understand foundational agentic concepts!

# %%
! pip install agent-framework --pre
# Out:
# Requirement already satisfied: agent-framework in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (1.0.0b251120)
# Requirement already satisfied: agent-framework-core[all] in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework) (1.0.0b251114)
# Requirement already satisfied: typing-extensions in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (4.13.2)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (2.11.4)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (2.9.1)
# Requirement already satisfied: opentelemetry-api>=1.24 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (2.8.1)
# Requirement already satisfied: azure-identity<2,>=1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.25.1)
# Requirement already satisfied: mcp>=1.13 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (1.23.1)
# Requirement already satisfied: packaging>=24.1 in c:\users\madasi\appdata\roaming\python\python313\site-packages (from agent-framework-core[all]->agent-framework) (25.0)
# Requirement already satisfied: agent-framework-a2a in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.0.0b251120)
# Requirement already satisfied: agent-framework-ag-ui in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.0.0b251120)
# Requirement already satisfied: agent-framework-anthropic in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.0.0b251120)
# Requirement already satisfied: agent-framework-azure-ai in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.0.0b251120)
# Requirement already satisfied: agent-framework-copilotstudio in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.0.0b251120)
# Requirement already satisfied: agent-framework-devui in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.0.0b251120)
# Requirement already satisfied: agent-framework-mem0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.0.0b251120)
# Requirement already satisfied: agent-framework-purview in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.0.0b251120)
# Requirement already satisfied: agent-framework-redis in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]->agent-framework) (1.0.0b251120)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from azure-identity<2,>=1->agent-framework-core[all]->agent-framework) (1.36.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from azure-identity<2,>=1->agent-framework-core[all]->agent-framework) (44.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from azure-identity<2,>=1->agent-framework-core[all]->agent-framework) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from azure-identity<2,>=1->agent-framework-core[all]->agent-framework) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->agent-framework-core[all]->agent-framework) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->agent-framework-core[all]->agent-framework) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->agent-framework-core[all]->agent-framework) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3,>=2->agent-framework-core[all]->agent-framework) (1.2.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core[all]->agent-framework) (2.32.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core[all]->agent-framework) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core[all]->agent-framework) (2.22)
# Requirement already satisfied: anyio>=4.5 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (4.24.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\madasi\appdata\roaming\python\python313\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (310)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (0.46.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (0.34.2)
# Requirement already satisfied: idna>=2.8 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (1.3.1)
# Requirement already satisfied: certifi in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (0.25.1)
# Requirement already satisfied: websockets>=15.0.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (15.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core[all]->agent-framework) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core[all]->agent-framework) (2.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from openai>=1.99.0->agent-framework-core[all]->agent-framework) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from openai>=1.99.0->agent-framework-core[all]->agent-framework) (0.12.0)
# Requirement already satisfied: tqdm>4 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from openai>=1.99.0->agent-framework-core[all]->agent-framework) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-api>=1.24->agent-framework-core[all]->agent-framework) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core[all]->agent-framework) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core[all]->agent-framework) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.66.2 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core[all]->agent-framework) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core[all]->agent-framework) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core[all]->agent-framework) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core[all]->agent-framework) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-sdk>=1.24->agent-framework-core[all]->agent-framework) (0.59b0)
# Requirement already satisfied: colorama in c:\users\madasi\appdata\roaming\python\python313\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core[all]->agent-framework) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core[all]->agent-framework) (8.1.8)
# Requirement already satisfied: a2a-sdk>=0.3.5 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-a2a->agent-framework-core[all]->agent-framework) (0.3.19)
# Requirement already satisfied: google-api-core>=1.26.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]->agent-framework) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]->agent-framework) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]->agent-framework) (2.43.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]->agent-framework) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]->agent-framework) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]->agent-framework) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]->agent-framework) (0.6.1)
# Requirement already satisfied: ag-ui-protocol>=0.1.9 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-ag-ui->agent-framework-core[all]->agent-framework) (0.1.10)
# Requirement already satisfied: fastapi>=0.115.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-ag-ui->agent-framework-core[all]->agent-framework) (0.115.12)
# Requirement already satisfied: anthropic<1,>=0.70.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-anthropic->agent-framework-core[all]->agent-framework) (0.75.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic->agent-framework-core[all]->agent-framework) (0.17.0)
# Requirement already satisfied: azure-ai-projects>=2.0.0b2 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (2.0.0b2)
# Requirement already satisfied: azure-ai-agents==1.2.0b5 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (1.2.0b5)
# Requirement already satisfied: aiohttp in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (3.11.18)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (0.7.2)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from azure-ai-projects>=2.0.0b2->agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (12.25.1)
# Requirement already satisfied: microsoft-agents-copilotstudio-client>=0.3.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-copilotstudio->agent-framework-core[all]->agent-framework) (0.6.1)
# Requirement already satisfied: microsoft-agents-hosting-core==0.6.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]->agent-framework) (0.6.1)
# Requirement already satisfied: microsoft-agents-activity==0.6.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from microsoft-agents-hosting-core==0.6.1->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]->agent-framework) (0.6.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework-core[all]->agent-framework) (0.6.4)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework-core[all]->agent-framework) (6.0.2)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework-core[all]->agent-framework) (1.0.5)
# Requirement already satisfied: mem0ai>=0.1.117 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-mem0->agent-framework-core[all]->agent-framework) (1.0.1)
# Requirement already satisfied: posthog>=3.5.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (7.0.1)
# Requirement already satisfied: pytz>=2024.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (1.16.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (2.0.41)
# Requirement already satisfied: six>=1.5 in c:\users\madasi\appdata\roaming\python\python313\site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\madasi\appdata\roaming\python\python313\site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (2.2.1)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (2.2.6)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (4.1.0)
# Requirement already satisfied: greenlet>=1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy>=2.0.31->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]->agent-framework) (3.2.2)
# Requirement already satisfied: redis>=6.4.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-redis->agent-framework-core[all]->agent-framework) (6.4.0)
# Requirement already satisfied: redisvl>=0.8.2 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-redis->agent-framework-core[all]->agent-framework) (0.12.1)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]->agent-framework) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]->agent-framework) (0.5.4)
# Requirement already satisfied: python-ulid>=3.0.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]->agent-framework) (3.1.0)
# Requirement already satisfied: tenacity>=8.2.2 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]->agent-framework) (9.1.2)
# Requirement already satisfied: ply in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from jsonpath-ng>=1.5.0->redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]->agent-framework) (3.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\madasi\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]->agent-framework) (1.20.0)

# %%
# 📚 Exploring Agentic Frameworks - Basic Agent Example
# This example demonstrates core concepts of the Microsoft Agent Framework

# 📦 Import Required Libraries
import os                     # For environment variable access
from random import randint    # For generating random selections

from dotenv import load_dotenv  # For loading .env configuration files

# %%
# 🤖 Import Core Agent Framework Components
# ChatAgent: The main conversational agent class
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs
from agent_framework import ChatAgent
from agent_framework.azure import AzureOpenAIChatClient

# %%
# 🔧 Initialize Environment Configuration
# Load environment variables from .env file
# This enables secure storage of API keys and endpoints
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function: Random Destination Generator
# This demonstrates how to create tools that agents can use
# Tools extend the agent's capabilities beyond just conversation
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    This function serves as a tool that the agent can call when it needs
    to suggest a random destination for travel planning.
    
    Returns:
        str: A randomly selected destination from the predefined list
    """
    # Curated list of popular vacation destinations worldwide
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a randomly selected destination
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client
# This demonstrates how to connect to GitHub Models (OpenAI-compatible API)
# The client handles all communication with the AI model
openai_chat_client = AzureOpenAIChatClient(
    endpoint=os.environ.get("AZUREOAI_ENDPOINT"),    # API endpoint URL
    api_key=os.environ.get("AZUREOAI_KEY"),        # Authentication token
    deployment_name=os.environ.get("AZUREOAI_MODEL_ID")  # Model identifier (e.g., gpt-4o)
)

# %%
# 🤖 Create the Basic Agent
# This demonstrates the core agent creation pattern in the framework
# Key components: chat client, instructions, and tools
agent = ChatAgent(
    chat_client=openai_chat_client,  # The AI model client for generating responses
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",  # System prompt defining agent behavior
    tools=[get_random_destination]   # List of available tools the agent can use
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# Let's plan a day trip to the vibrant city of Rio de Janeiro, Brazil! Here's a suggested itinerary:
#
# ### Morning:
# 1. **Sugarloaf Mountain (Pão de Açúcar)**
#    - Start your day with a breathtaking cable car ride to Sugarloaf Mountain.
#    - Enjoy panoramic views of the city, beaches, and the Guanabara Bay.
#
# 2. **Breakfast at Café Confeitaria Colombo**
#    - Head to this historic café for a delicious Brazilian breakfast with coffee, fresh juices, and pão de queijo (cheese bread).
#
# ---
#
# ### Afternoon:
# 3. **Christ the Redeemer (Cristo Redentor)**
#    - Visit the iconic Christ the Redeemer statue atop Corcovado Mountain.
#    - Explore the lush Tijuca National Park surrounding the site.
#
# 4. **Lunch in Santa Teresa**
#    - Dine in the charming Santa Teresa neighborhood, famous for its bohemian vibe and excellent restaurants.
#
# 5. **Explore Lapa and the Selarón Steps**
#    - Take a short stroll to the colorful Escadaria Selarón, a beautiful mosaic staircase.
#    - Explore the nearby Lapa Arches and soak in the lively atmosphere.
#
# ---
#
# ### Evening:
# 6. **Copacabana or Ipanema Beach**
#    - Relax at one of Rio's famous beaches: Copacabana or Ipanema.
#    - Enjoy the sunset while sipping on refreshing coconut water or a classic "caipirinha."
#
# 7. **Dinner by the Beach**
#    - End your day with a seafood dinner at a beachside restaurant.
#
# ---
#
# Let me know if you'd like more help customizing this to your needs!

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Let's plan a day trip to the romantic city of Paris, France! Here's your itinerary:
#
# ---
#
# ### Morning:
# 1. **Visit the Eiffel Tower**
#    - Start your day by heading to the Eiffel Tower. Enjoy the view from the top, or take a morning stroll around the Champ de Mars gardens.
#
# 2. **Breakfast at a Parisian Café**
#    - Stop at a nearby café to savor a classic Parisian breakfast of croissants, baguettes, jam, and a café au lait.
#
# ---
#
# ### Afternoon:
# 3. **Explore the Louvre Museum**
#    - Spend time at the Louvre, exploring iconic art pieces like the Mona Lisa and Venus de Milo.
#    - Walk along the picturesque Tuileries Garden right next to the museum.
#
# 4. **Lunch by the Seine River**
#    - Have a relaxing lunch at a bistro by the Seine River. Try some French cuisines like quiche, ratatouille, or croque monsieur.
#
# 5. **Stroll Along the Seine and Visit Notre-Dame**
#    - Enjoy a scenic walk along the Seine River.
#    - Stop by the historic Notre-Dame Cathedral (exterior view, as renovations may still be ongoing).
#
# ---
#
# ### Evening:
# 6. **Montmartre and Sacré-Cœur Basilica**
#    - Head to the artistic Montmartre neighborhood; explore the charming streets and visit the Sacré-Cœur Basilica.
#    - Watch the sunset from the steps of Sacré-Cœur for an incredible view over Paris.
#
# 7. **Dinner at a Classic French Brasserie**
#    - End the day with a memorable dinner in Montmartre. Try French delicacies like coq au vin or duck confit with a glass of wine.
#
# ---
#
# Let me know if you want to adjust or refine your day trip in Paris!
