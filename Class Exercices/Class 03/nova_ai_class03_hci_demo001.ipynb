# %%
key = "AZURE_TEXT_ANALYTICS_KEY"
endpoint = "AZURE_TEXT_ANALYTICS_ENDPOINT"

from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

# %%
# Authenticate the client using your key and endpoint 
def authenticate_client():
    ta_credential = AzureKeyCredential(key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=endpoint, 
            credential=ta_credential)
    return text_analytics_client

# %%
client = authenticate_client()

# %%
# Example function for extracting information from healthcare-related text 
def health_example(client):
    documents = [
        """
        Patient needs to take 50 mg of ibuprofen.
        """
    ]

    poller = client.begin_analyze_healthcare_entities(documents)
    result = poller.result()

    docs = [doc for doc in result if not doc.is_error]

    for idx, doc in enumerate(docs):
        for entity in doc.entities:
            print("Entity: {}".format(entity.text))
            print("...Normalized Text: {}".format(entity.normalized_text))
            print("...Category: {}".format(entity.category))
            print("...Subcategory: {}".format(entity.subcategory))
            print("...Offset: {}".format(entity.offset))
            print("...Confidence score: {}".format(entity.confidence_score))
        for relation in doc.entity_relations:
            print("Relation of type: {} has the following roles".format(relation.relation_type))
            for role in relation.roles:
                print("...Role '{}' with entity '{}'".format(role.name, role.entity.text))
        print("------------------------------------------")

# %%
health_example(client)
# Out:
# ---------------------------------------------------------------------------
# ServiceRequestError                       Traceback (most recent call last)
# c:\code\NOVA\AI Class\nova_ai_class03_hci_demo001.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> health_example(client)
#
# c:\code\NOVA\AI Class\nova_ai_class03_hci_demo001.ipynb Cell 5 line 9
#       <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> def health_example(client):
#       <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a>     documents = [
#       <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>         """
#       <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>         Patient needs to take 50 mg of ibuprofen.
#       <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>         """
#       <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>     ]
# ----> <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>     poller = client.begin_analyze_healthcare_entities(documents)
#      <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a>     result = poller.result()
#      <a href='vscode-notebook-cell:/c%3A/code/NOVA/AI%20Class/nova_ai_class03_hci_demo001.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>     docs = [doc for doc in result if not doc.is_error]
#
# File c:\Python310\lib\site-packages\azure\core\tracing\decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      76 span_impl_type = settings.tracing_implementation()
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#      81 if merge_span and not passed_in_parent:
#
# File c:\Python310\lib\site-packages\azure\ai\textanalytics\_validate.py:79, in validate_multiapi_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      77 # the latest version is selected, we assume all features supported
#      78 if selected_api_version == VERSIONS_SUPPORTED[-1]:
# ---> 79     return func(*args, **kwargs)
#      81 if version_method_added and version_method_added != selected_api_version and \
#      82         VERSIONS_SUPPORTED.index(selected_api_version) < VERSIONS_SUPPORTED.index(version_method_added):
#      83     raise ValueError(
#      84         f"'{client.__class__.__name__}.{func.__name__}' is not available in API version "
#      85         f"{selected_api_version}. Use service API version {version_method_added} or newer."
#      86     )
#
# File c:\Python310\lib\site-packages\azure\ai\textanalytics\_text_analytics_client.py:760, in TextAnalyticsClient.begin_analyze_healthcare_entities(self, documents, continuation_token, disable_service_logs, display_name, language, model_version, polling_interval, show_stats, string_index_type, **kwargs)
#     752 if is_language_api(self._api_version):
#     753     input_docs = models.MultiLanguageAnalysisInput(
#     754         documents=docs
#     755     )
#     756     return cast(
#     757         AnalyzeHealthcareEntitiesLROPoller[
#     758             ItemPaged[Union[AnalyzeHealthcareEntitiesResult, DocumentError]]
#     759         ],
# --> 760         self._client.begin_analyze_text_submit_job(  # type: ignore
#     761             body=models.AnalyzeTextJobsInput(
#     762                 analysis_input=input_docs,
#     763                 display_name=display_name,
#     764                 tasks=[
#     765                     models.HealthcareLROTask(
#     766                         task_name="0",
#     767                         parameters=models.HealthcareTaskParameters(
#     768                             model_version=model_version,
#     769                             logging_opt_out=disable_service_logs,
#     770                             string_index_type=string_index_type_compatibility(string_index_type_arg),
#     771                         )
#     772                     )
#     773                 ]
#     774             ),
#     775             cls=my_cls,
#     776             polling=AnalyzeHealthcareEntitiesLROPollingMethod(
#     777                 text_analytics_client=self._client,
#     778                 timeout=polling_interval_arg,
#     779                 show_stats=show_stats,
#     780                 doc_id_order=doc_id_order,
#     781                 lro_algorithms=[
#     782                     TextAnalyticsOperationResourcePolling(
#     783                         show_stats=show_stats,
#     784                     )
#     785                 ],
#     786                 **kwargs
#     787             ),
#     788             continuation_token=continuation_token,
#     789             poller_cls=AnalyzeHealthcareEntitiesLROPoller,
#     790             **kwargs
#     791         )
#     792     )
#     794 # v3.1
#     795 return cast(
#     796     AnalyzeHealthcareEntitiesLROPoller[
#     797         ItemPaged[Union[AnalyzeHealthcareEntitiesResult, DocumentError]]
#    (...)
#     819     )
#     820 )
#
# File c:\Python310\lib\site-packages\azure\ai\textanalytics\_generated\_operations_mixin.py:285, in TextAnalyticsClientOperationsMixin.begin_analyze_text_submit_job(self, body, **kwargs)
#     283 mixin_instance._serialize.client_side_validation = False
#     284 mixin_instance._deserialize = Deserializer(self._models_dict(api_version))
# --> 285 return mixin_instance.begin_analyze_text_submit_job(body, **kwargs)
#
# File c:\Python310\lib\site-packages\azure\core\tracing\decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      76 span_impl_type = settings.tracing_implementation()
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#      81 if merge_span and not passed_in_parent:
#
# File c:\Python310\lib\site-packages\azure\ai\textanalytics\_generated\v2023_04_01\operations\_patch.py:67, in TextAnalyticsClientOperationsMixin.begin_analyze_text_submit_job(self, body, **kwargs)
#      65 cont_token = kwargs.pop('continuation_token', None)  # type: Optional[str]
#      66 if cont_token is None:
# ---> 67     raw_result = self._analyze_text_submit_job_initial(  # type: ignore
#      68         body=body,
#      69         api_version=api_version,
#      70         content_type=content_type,
#      71         cls=lambda x,y,z: x,
#      72         headers=_headers,
#      73         params=_params,
#      74         **kwargs
#      75     )
#      76 kwargs.pop('error_map', None)
#      78 def get_long_running_output(pipeline_response):
#
# File c:\Python310\lib\site-packages\azure\ai\textanalytics\_generated\v2023_04_01\operations\_text_analytics_client_operations.py:353, in TextAnalyticsClientOperationsMixin._analyze_text_submit_job_initial(self, body, **kwargs)
#     348 path_format_arguments = {
#     349     "Endpoint": self._serialize.url("self._config.endpoint", self._config.endpoint, 'str', skip_quote=True),
#     350 }
#     351 request.url = self._client.format_url(request.url, **path_format_arguments)  # type: ignore
# --> 353 pipeline_response = self._client._pipeline.run(  # type: ignore # pylint: disable=protected-access
#     354     request,
#     355     stream=False,
#     356     **kwargs
#     357 )
#     359 response = pipeline_response.http_response
#     361 if response.status_code not in [200, 202]:
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\_base.py:230, in Pipeline.run(self, request, **kwargs)
#     228 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     229 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 230 return first_node.send(pipeline_request)
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 86 (2 times)]
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\policies\_redirect.py:197, in RedirectPolicy.send(self, request)
#     195 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     196 while retryable:
# --> 197     response = self.next.send(request)
#     198     redirect_location = self.get_redirect_location(response)
#     199     if redirect_location and redirect_settings["allow"]:
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\policies\_retry.py:553, in RetryPolicy.send(self, request)
#     551                 is_response_error = True
#     552             continue
# --> 553     raise err
#     554 finally:
#     555     end_time = time.time()
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\policies\_retry.py:531, in RetryPolicy.send(self, request)
#     529 try:
#     530     self._configure_timeout(request, absolute_timeout, is_response_error)
# --> 531     response = self.next.send(request)
#     532     if self.is_retry(retry_settings, response):
#     533         retry_active = self.increment(retry_settings, response=response)
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 86 (4 times)]
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\_base.py:119, in _TransportRunner.send(self, request)
#     109 """HTTP transport send method.
#     110
#     111 :param request: The PipelineRequest object.
#    (...)
#     114 :rtype: ~azure.core.pipeline.PipelineResponse
#     115 """
#     116 cleanup_kwargs_for_transport(request.context.options)
#     117 return PipelineResponse(
#     118     request.http_request,
# --> 119     self._sender.send(request.http_request, **request.context.options),
#     120     context=request.context,
#     121 )
#
# File c:\Python310\lib\site-packages\azure\core\pipeline\transport\_requests_basic.py:381, in RequestsTransport.send(self, request, **kwargs)
#     378     error = ServiceRequestError(err, error=err)
#     380 if error:
# --> 381     raise error
#     382 if _is_rest(request):
#     383     from azure.core.rest._requests_basic import RestRequestsTransportResponse
#
# ServiceRequestError: Invalid URL 'AZURE_TEXT_ANALYTICS_ENDPOINT/language/analyze-text/jobs?api-version=2023-04-01': No scheme supplied. Perhaps you meant http://AZURE_TEXT_ANALYTICS_ENDPOINT/language/analyze-text/jobs?api-version=2023-04-01?
